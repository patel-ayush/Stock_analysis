# %%
import numpy as np
import pandas as pd
import yfinance as yf
import plotly.graph_objs as go
import matplotlib.pyplot as plt
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2019-05-28  126.319313  126.806885  124.541107  124.722755  107.598114
# 2019-05-29  124.282982  124.550667  122.676865  123.986618  106.963051
# 2019-05-30  124.034416  124.254303  123.260040  123.871895  106.864067
# 2019-05-31  122.791588  122.791588  121.271507  121.405357  104.736198
# 2019-06-03  121.510513  122.906311  121.472275  122.629066  105.791885
#
#              Volume  Day_Perc_Change
# Date
# 2019-05-28  5134605              NaN
# 2019-05-29  3848234        -0.590219
# 2019-05-30  2868027        -0.092529
# 2019-05-31  3702108        -1.991200
# 2019-06-03  4463177         1.007953

# %% [markdown]
# # Daily Return

# %%
from sklearn.preprocessing import StandardScaler ,MinMaxScaler 

def plot_returns(ind_c, us_c ,p ,i):
    data_ind = yf.download(tickers=ind_c, 
                       period=p, 
                       interval=i)
    
    data_us = yf.download(tickers=us_c, 
                       period=p, 
                       interval=i)
    
    plt.figure(figsize = (16, 4))

    data_ind['Day_Perc_Change'] = data_ind['Close'].pct_change()*100
    data_ind.dropna(axis = 0, inplace = True)
    

    plt.subplot(1, 2, 1)
    plt.title("Title")
    plt.plot(data_ind['Day_Perc_Change'])
    plt.xticks(rotation=45)
    plt.ylabel("Returns")
    plt.xlabel("Date")
    
    data_us['Day_Perc_Change'] = data_us['Close'].pct_change()*100
    data_us.dropna(axis = 0, inplace = True)
    
    plt.subplot(1, 2, 2)
    plt.title("Title")
    plt.plot(data_us['Day_Perc_Change'])
    plt.xticks(rotation=45)
    plt.ylabel("Returns")
    plt.xlabel("Date")
    
    
    plt.show()

# %%
plot_returns('RALLIS.NS','IBM','3y','1d')
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
def plot_close(ind_c, us_c ,p ,i):
    data_ind = yf.download(tickers=ind_c, 
                       period=p, 
                       interval=i)
    
    data_us = yf.download(tickers=us_c, 
                          period=p, 
                          interval=i)
    
    plt.figure(figsize = (16, 4))
    
    plt.subplot(1, 2, 1)
    plt.title("Title")
    plt.plot(data_ind['Close'])
    plt.xticks(rotation=45)
    plt.ylabel("Stock Price")
    plt.xlabel("Date")
    
    plt.subplot(1, 2, 2)
    plt.title("Title")
    plt.plot(data_us['Close'])
    plt.xticks(rotation=45)
    plt.ylabel("Stock Price")
    plt.xlabel("Date")

    plt.show()
    
    plt.figure(figsize = (16, 4))
    ss= MinMaxScaler()
    xi = ss.fit_transform(np.array(data_ind['Close']).reshape(-1,1))
    xu = ss.fit_transform(np.array(data_us['Close']).reshape(-1,1))

    print(xi.shape,data.shape)
    plt.plot(data_ind.index ,xi.reshape(-1,))
    plt.plot(data_us.index ,xu.reshape(-1,))
    ini ,final ='2019-12-31' , '2020-05-03'
    plt.fill_between( data.index,
                      1,0,
                      where=(data.index < final) & (data.index > ini) ,
                      alpha=0.2)
    
    plt.xticks(rotation=45)
    plt.ylabel("Stock Price")
    plt.xlabel("Date")
    plt.show()
    
plot_close('RALLIS.NS','IBM','5y','1d')
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# (1236, 1) (758, 7)

# %%
names ={"IBM":"IBM compnay"}
names['IBM']
# Out:
# 'IBM compnay'

# %%
plt.plot(data['Close'])

# %%
def plot_wave(ini , final):
    plt.figure(figsize = (16, 5))
    plt.plot(data['Close'])
    plt.fill_between( data.index,
                      max(data['Close']),
                      min(data['Close']) ,
                      where=(data.index < final) & (data.index > ini) ,
                      alpha=0.5)
    
plot_wave('2019-05-31' , '2020-06-03')

# %%
data[data.index=='2019-06-03'].index
# Out:
# DatetimeIndex(['2019-06-03'], dtype='datetime64[ns]', name='Date', freq=None)

# %%
data
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2019-05-29  124.282982  124.550667  122.676865  123.986618  106.963051
# 2019-05-30  124.034416  124.254303  123.260040  123.871895  106.864067
# 2019-05-31  122.791588  122.791588  121.271507  121.405357  104.736198
# 2019-06-03  121.510513  122.906311  121.472275  122.629066  105.791885
# 2019-06-04  123.862335  126.902489  123.413002  126.854683  109.437325
# ...                ...         ...         ...         ...         ...
# 2022-05-23  129.500000  131.949997  129.419998  131.169998  131.169998
# 2022-05-24  130.570007  134.369995  130.419998  133.800003  133.800003
# 2022-05-25  132.860001  134.820007  132.860001  134.389999  134.389999
# 2022-05-26  135.000000  137.550003  134.520004  136.889999  136.889999
# 2022-05-27  137.389999  139.740005  137.240005  139.270004  139.270004
#
#              Volume  Day_Perc_Change
# Date
# 2019-05-29  3848234        -0.590219
# 2019-05-30  2868027        -0.092529
# 2019-05-31  3702108        -1.991200
# 2019-06-03  4463177         1.007953
# 2019-06-04  4093521         3.445852
# ...             ...              ...
# 2022-05-23  3591500         2.093713
# 2022-05-24  4189700         2.005035
# 2022-05-25  3299300         0.440954
# 2022-05-26  3929300         1.860257
# 2022-05-27  4608000         1.738626
#
# [758 rows x 7 columns]
